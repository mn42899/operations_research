# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# %%
# Load the dataset
hotels_df = pd.read_csv('https://raw.githubusercontent.com/kristxna/Datasets/refs/heads/main/hotels.csv')

# %%
hotels_df.columns
# Out:
# Index(['Room_ID', 'Floor', 'Square_Feet', 'Cleaning_Time_Hours'], dtype='object')

# %%
hotels_df.head()
# Out:
#    Room_ID  Floor  Square_Feet  Cleaning_Time_Hours
# 0        1      3          682             1.814545
# 1        2      9          223             0.562727
# 2        3      7          506             1.334545
# 3        4      1          561             1.484545
# 4        5     14          424             1.110909

# %%
print("\n=================== Original Optimization Model ===================")

# Extract relevant data
floors = hotels_df['Floor'].unique()
rooms = hotels_df['Room_ID'].unique()
num_attendants = 8
max_sqft_per_day = 3500
max_overtime_hours = 2
base_wage = 25
extra_floor_cost = 75

def get_room_data():
    room_data = {}
    for _, row in hotels_df.iterrows():
        floor, room, sqft, time = row['Floor'], row['Room_ID'], row['Square_Feet'], row['Cleaning_Time_Hours']
        if floor not in room_data:
            room_data[floor] = []
        room_data[floor].append((room, sqft, time))
    return room_data

room_data = get_room_data()

# Initialize model 
model = gp.Model("Hotel Cleaning Scheduling")

# Decision Variables
x = model.addVars(num_attendants, floors, rooms, vtype=GRB.BINARY, name="Assign")
f = model.addVars(num_attendants, floors, vtype=GRB.BINARY, name="FloorAssign")
overtime = model.addVars(num_attendants, vtype=GRB.INTEGER, lb=0, ub=max_overtime_hours, name="Overtime")
over_sqft = model.addVars(num_attendants, vtype=GRB.BINARY, name="OverSqft")
floor_violation = model.addVars(num_attendants, vtype=GRB.INTEGER, lb=0, name="FloorViolation")

# Objective Function: Minimize cost
model.setObjective(
    gp.quicksum(base_wage * 8 + 1.5 * base_wage * overtime[i] + extra_floor_cost * floor_violation[i] 
                + 2 * base_wage * over_sqft[i] for i in range(num_attendants)), GRB.MINIMIZE)

# Constraints
# Ensure all rooms are assigned to one attendant
for k in floors:
    for j in room_data[k]:
        model.addConstr(gp.quicksum(x[i, k, j[0]] for i in range(num_attendants)) == 1, f"RoomAssignment_{k}_{j[0]}")

# Floor assignment consistency
for i in range(num_attendants):
    for k in floors:
        for j in room_data[k]:
            model.addConstr(x[i, k, j[0]] <= f[i, k], f"FloorConsistency_{i}_{k}_{j[0]}")

# Each attendant cleans between 2 to 4 floors
for i in range(num_attendants):
    model.addConstr(gp.quicksum(f[i, k] for k in floors) >= 2, f"MinFloors_{i}")
    model.addConstr(gp.quicksum(f[i, k] for k in floors) <= 4, f"MaxFloors_{i}")

# Track extra floor violations (if more than 2 floors, record the extra count)
for i in range(num_attendants):
    model.addConstr(floor_violation[i] >= gp.quicksum(f[i, k] for k in floors) - 2, f"TrackFloorViolations_{i}")

# Ensure attendants do not exceed 3500 sqft before extra pay applies
for i in range(num_attendants):
    model.addConstr(
        gp.quicksum(x[i, k, j[0]] * j[1] for k in floors for j in room_data[k]) <= max_sqft_per_day + over_sqft[i] * 5000,
        f"SqFtLimit_{i}"
    )

# Ensure attendants work within 8 hours with a maximum of 2 overtime hours
for i in range(num_attendants):
    model.addConstr(gp.quicksum(x[i, k, j[0]] * j[2] for k in floors for j in room_data[k]) <= 8 + overtime[i], f"WorkHours_{i}")

# Solve the model
model.optimize()

# Display results
if model.status == GRB.OPTIMAL:
    total_overtime = sum(overtime[i].x for i in range(num_attendants))
    total_floor_violations = sum(floor_violation[i].x for i in range(num_attendants))
    print(f"Optimal Staffing Cost for the Day: ${model.objVal:.2f}")
    print(f"Total Overtime Hours: {total_overtime}")
    print(f"Total Floor Violations: {total_floor_violations}")

    print("\n Attendant Summary:")
    for i in range(num_attendants):
        assigned_floors = [k for k in floors if f[i, k].x > 0.5]
        num_floors = len(assigned_floors)
        total_sqft_cleaned = sum(x[i, k, j[0]].x * j[1] for k in floors for j in room_data[k])
        overtime_hours = int(overtime[i].x)
        floor_violations = int(floor_violation[i].x)
        
        extra_sqft_pay = 2 * base_wage * (total_sqft_cleaned > max_sqft_per_day)
        extra_floor_pay = extra_floor_cost * floor_violations
        
        total_wage = (base_wage * 8) + (1.5 * base_wage * overtime_hours) + extra_sqft_pay + extra_floor_pay

        print(f"Attendant {i+1}: Floors [{', '.join(map(str, assigned_floors))}], "
              f"Overtime: {overtime_hours} hours, Total Sqft Cleaned: {total_sqft_cleaned:.2f}, "
              f"Floor Violations: {floor_violations}, Total Wage: ${total_wage:.2f}")
else:
    print("No optimal solution found.")
# Out:
# =================== Original Optimization Model ===================
# Set parameter Username
# Set parameter LicenseID to value 2610046
# Academic license - for non-commercial use only - expires 2026-01-14
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 508 rows, 5960 columns and 2440 nonzeros
# Model fingerprint: 0x4b78e7b7
# Variable types: 0 continuous, 5960 integer (5944 binary)
# Coefficient statistics:
#   Matrix range     [6e-01, 5e+03]
#   Objective range  [4e+01, 8e+01]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 3162.5000000
# Presolve removed 16 rows and 5408 columns
# Presolve time: 0.01s
# Presolved: 492 rows, 552 columns, 2216 nonzeros
# Variable types: 0 continuous, 552 integer (536 binary)
#
# Root relaxation: objective 1.660511e+03, 576 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1660.51136    0   81 3162.50000 1660.51136  47.5%     -    0s
# H    0     0                    1900.0000000 1660.51136  12.6%     -    0s
# H    0     0                    1862.5000000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0  117 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0  133 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0   72 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0   89 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0   86 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0   88 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0  118 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0  112 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0   52 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0   66 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0  112 1862.50000 1660.51136  10.8%     -    0s
#      0     0 1660.51136    0  104 1862.50000 1660.51136  10.8%     -    0s
#      0     2 1660.51136    0  104 1862.50000 1660.51136  10.8%     -    0s
# H   78    76                    1825.0000000 1660.51136  9.01%   238    0s
# H  339   264                    1800.0000000 1660.51136  7.75%  96.3    0s
# H  943   526                    1787.5000000 1660.51136  7.10%  66.1    0s
# H  966   437                    1750.0000000 1660.51136  5.11%  66.7    0s
#  10121   723     cutoff   24      1750.00000 1687.30720  3.58%  98.2    5s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 15444 nodes (1365137 simplex iterations) in 6.18 seconds (13.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 1750 1787.5 1800 ... 3162.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.750000000000e+03, best bound 1.750000000000e+03, gap 0.0000%
# Optimal Staffing Cost for the Day: $1750.00
# Total Overtime Hours: 4.0
# Total Floor Violations: 0.0
#
#  Attendant Summary:
# Attendant 1: Floors [3, 8], Overtime: 1 hours, Total Sqft Cleaned: 3230.00, Floor Violations: 0, Total Wage: $237.50
# Attendant 2: Floors [9, 5], Overtime: 1 hours, Total Sqft Cleaned: 3383.00, Floor Violations: 0, Total Wage: $237.50
# Attendant 3: Floors [14, 10], Overtime: 0 hours, Total Sqft Cleaned: 2922.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 4: Floors [7, 6], Overtime: 0 hours, Total Sqft Cleaned: 2617.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 5: Floors [4, 12], Overtime: 0 hours, Total Sqft Cleaned: 3044.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 6: Floors [1, 11], Overtime: 1 hours, Total Sqft Cleaned: 3393.00, Floor Violations: 0, Total Wage: $237.50
# Attendant 7: Floors [12, 2], Overtime: 0 hours, Total Sqft Cleaned: 2971.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 8: Floors [13, 5], Overtime: 1 hours, Total Sqft Cleaned: 3365.00, Floor Violations: 0, Total Wage: $237.50

# %%
# Verify all rooms are assigned
all_rooms_cleaned = True
uncleaned_rooms = []

for k in floors:
    for j in room_data[k]:
        assigned = sum(x[i, k, j[0]].x for i in range(num_attendants))  # Summing assignments
        if assigned != 1:
            all_rooms_cleaned = False
            uncleaned_rooms.append((j[0], k))  # Collect uncleaned rooms

if all_rooms_cleaned:
    print("All rooms were assigned and cleaned.")
else:
    print("Some rooms were not cleaned!")
    print(f"Uncleaned rooms: {uncleaned_rooms}")
# Out:
# All rooms were assigned and cleaned.

# %%
# 2. d)

# %%
# (f) Model relaxation
print("\n=================== Relaxed Model ===================")
relaxed_model = model.relax() 
relaxed_model.optimize()

if relaxed_model.status == GRB.OPTIMAL:
    print(f"(f) Relaxed Model Cost: ${relaxed_model.objVal:.2f}")

    # Attendant Summary for Relaxed Model
    print("\nAttendant Summary for Relaxed Model:")
    for i in range(num_attendants):
        overtime_hours = max(0, round(relaxed_model.getVarByName(f"Overtime[{i}]").x, 2)) if relaxed_model.getVarByName(f"Overtime[{i}]") else 0
        floor_violations = int(relaxed_model.getVarByName(f"FloorViolation[{i}]").x) if relaxed_model.getVarByName(f"FloorViolation[{i}]") else 0
        total_sqft_cleaned = sum(x[i, k, j[0]].x * j[1] for k in floors for j in room_data[k])

        # Wage calculations
        base_pay = base_wage * 8
        overtime_pay = 1.5 * base_wage * overtime_hours
        extra_sqft_pay = 2 * base_wage * (total_sqft_cleaned > max_sqft_per_day)
        extra_floor_pay = extra_floor_cost * floor_violations
        total_wage = base_pay + overtime_pay + extra_sqft_pay + extra_floor_pay

        assigned_floors = [k for k in floors if f[i, k].x > 0.5]

        print(f"Attendant {i+1}: Floors [{', '.join(map(str, assigned_floors))}], "
              f"Overtime: {overtime_hours:.2f} hours, Total Sqft Cleaned: {total_sqft_cleaned:.2f}, "
              f"Floor Violations: {floor_violations}, Total Wage: ${total_wage:.2f}")
else:
    print("No optimal solution found for the relaxed model.")
# Out:
# =================== Relaxed Model ===================
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 508 rows, 5960 columns and 2440 nonzeros
# Model fingerprint: 0x41ad9c95
# Coefficient statistics:
#   Matrix range     [6e-01, 5e+03]
#   Objective range  [4e+01, 8e+01]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 8 rows and 5408 columns
# Presolve time: 0.00s
# Presolved: 500 rows, 560 columns, 2336 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6605114e+03   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        8 DPushes remaining with DInf 0.0000000e+00                 0s
#
#      468 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0864236e-13      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      471    1.6605114e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 471 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.660511364e+03
# (f) Relaxed Model Cost: $1660.51
#
# Attendant Summary for Relaxed Model:
# Attendant 1: Floors [3, 8], Overtime: 0.41 hours, Total Sqft Cleaned: 3230.00, Floor Violations: 0, Total Wage: $215.38
# Attendant 2: Floors [9, 5], Overtime: 0.00 hours, Total Sqft Cleaned: 3383.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 3: Floors [14, 10], Overtime: 0.00 hours, Total Sqft Cleaned: 2922.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 4: Floors [7, 6], Overtime: 0.00 hours, Total Sqft Cleaned: 2617.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 5: Floors [4, 12], Overtime: 1.20 hours, Total Sqft Cleaned: 3044.00, Floor Violations: 0, Total Wage: $245.00
# Attendant 6: Floors [1, 11], Overtime: 0.00 hours, Total Sqft Cleaned: 3393.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 7: Floors [12, 2], Overtime: 0.00 hours, Total Sqft Cleaned: 2971.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 8: Floors [13, 5], Overtime: 0.00 hours, Total Sqft Cleaned: 3365.00, Floor Violations: 0, Total Wage: $200.00

# %%
# Part (g) Convert binary to continuous and solve manually relaxed problem
print("\n=================== Manually Relaxed Model ===================")

# Make a copy of the model to manually relax it
manual_relax_model = model.copy()

# Convert all decision variables to continuous
for v in manual_relax_model.getVars():
    v.vtype = GRB.CONTINUOUS

manual_relax_model.optimize()

if manual_relax_model.status == GRB.OPTIMAL:
    print(f"(g) Manually Relaxed Solution Cost: ${manual_relax_model.objVal:.2f}")

    # Attendant Summary
    print("\nAttendant Summary for Manually Relaxed Model:")
    for i in range(num_attendants):
        overtime_hours = max(0, round(manual_relax_model.getVarByName(f"Overtime[{i}]").x, 2)) if manual_relax_model.getVarByName(f"Overtime[{i}]") else 0
        floor_violations = int(manual_relax_model.getVarByName(f"FloorViolation[{i}]").x) if manual_relax_model.getVarByName(f"FloorViolation[{i}]") else 0
        total_sqft_cleaned = sum(x[i, k, j[0]].x * j[1] for k in floors for j in room_data[k])

        # Wage calculations
        base_pay = base_wage * 8
        overtime_pay = 1.5 * base_wage * overtime_hours
        extra_sqft_pay = 2 * base_wage * (total_sqft_cleaned > max_sqft_per_day)
        extra_floor_pay = extra_floor_cost * floor_violations
        total_wage = base_pay + overtime_pay + extra_sqft_pay + extra_floor_pay

        assigned_floors = [k for k in floors if f[i, k].x > 0.5]

        print(f"Attendant {i+1}: Floors [{', '.join(map(str, assigned_floors))}], "
              f"Overtime: {overtime_hours:.2f} hours, Total Sqft Cleaned: {total_sqft_cleaned:.2f}, "
              f"Floor Violations: {floor_violations}, Total Wage: ${total_wage:.2f}")
else:
    print("No optimal solution found for the manually relaxed model.")
# Out:
# =================== Manually Relaxed Model ===================
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 508 rows, 5960 columns and 2440 nonzeros
# Model fingerprint: 0x41ad9c95
# Coefficient statistics:
#   Matrix range     [6e-01, 5e+03]
#   Objective range  [4e+01, 8e+01]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 8 rows and 5408 columns
# Presolve time: 0.00s
# Presolved: 500 rows, 560 columns, 2336 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6605114e+03   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        8 DPushes remaining with DInf 0.0000000e+00                 0s
#
#      468 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0864236e-13      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      471    1.6605114e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 471 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.660511364e+03
# (g) Manually Relaxed Solution Cost: $1660.51
#
# Attendant Summary for Manually Relaxed Model:
# Attendant 1: Floors [3, 8], Overtime: 0.41 hours, Total Sqft Cleaned: 3230.00, Floor Violations: 0, Total Wage: $215.38
# Attendant 2: Floors [9, 5], Overtime: 0.00 hours, Total Sqft Cleaned: 3383.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 3: Floors [14, 10], Overtime: 0.00 hours, Total Sqft Cleaned: 2922.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 4: Floors [7, 6], Overtime: 0.00 hours, Total Sqft Cleaned: 2617.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 5: Floors [4, 12], Overtime: 1.20 hours, Total Sqft Cleaned: 3044.00, Floor Violations: 0, Total Wage: $245.00
# Attendant 6: Floors [1, 11], Overtime: 0.00 hours, Total Sqft Cleaned: 3393.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 7: Floors [12, 2], Overtime: 0.00 hours, Total Sqft Cleaned: 2971.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 8: Floors [13, 5], Overtime: 0.00 hours, Total Sqft Cleaned: 3365.00, Floor Violations: 0, Total Wage: $200.00

# %%
print(f"Binary Model Cost: ${model.objVal:.2f}")
print(f"Relaxed Model Cost: ${relaxed_model.objVal:.2f}")
# Out:
# Binary Model Cost: $1750.00
# Relaxed Model Cost: $1660.51

# %%
# Part (i) Adjust overtime multiplier to 2.0 and re-optimize
print("\n=================== Updated Model with 2x Overtime Pay ===================")

overtime_multiplier = 2.0
model_i = model.copy()  # Copy the original model

# Update Objective Function
model_i.setObjective(
    gp.quicksum(base_wage * 8 * (1 + model_i.getVarByName(f"OverSqft[{i}]")) + 
                base_wage * overtime_multiplier * model_i.getVarByName(f"Overtime[{i}]") for i in range(num_attendants)) +
    gp.quicksum(extra_floor_cost * model_i.getVarByName(f"FloorViolation[{i}]") for i in range(num_attendants)),
    GRB.MINIMIZE
)

model_i.optimize()

# Display Results
if model_i.status == GRB.OPTIMAL:
    print(f"(i) Updated Optimal Cost with 2x Overtime: ${model_i.objVal:.2f}")

    # Attendant Summary for 2x Overtime Model
    print("\nAttendant Summary for Updated Model with 2x Overtime Pay:")
    for i in range(num_attendants):
        assigned_floors = [k for k in floors if f[i, k].x > 0.5]
        num_floors = len(assigned_floors)

        # Floor Violation Calculation
        if num_floors <= 2:
            floor_violations = 0
        else:
            floor_violations = num_floors - 2  # Count excess floors

        overtime_hours = max(0, round(model_i.getVarByName(f"Overtime[{i}]").x, 2)) if model_i.getVarByName(f"Overtime[{i}]") else 0
        total_sqft_cleaned = sum(x[i, k, j[0]].x * j[1] for k in floors for j in room_data[k])

        # Wage calculations
        base_pay = base_wage * 8
        overtime_pay = overtime_multiplier * base_wage * overtime_hours
        extra_sqft_pay = (2 * base_wage * 8) if total_sqft_cleaned > max_sqft_per_day else 0  
        extra_floor_pay = extra_floor_cost * floor_violations
        total_wage = base_pay + overtime_pay + extra_sqft_pay + extra_floor_pay

        print(f"Attendant {i+1}: Floors [{', '.join(map(str, assigned_floors))}], "
              f"Overtime: {overtime_hours:.2f} hours, Total Sqft Cleaned: {total_sqft_cleaned:.2f}, "
              f"Floor Violations: {floor_violations}, Total Wage: ${total_wage:.2f}")
else:
    print("No optimal solution found for the updated model with 2x overtime pay.")
# Out:
# =================== Updated Model with 2x Overtime Pay ===================
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 508 rows, 5960 columns and 2440 nonzeros
# Model fingerprint: 0x0af6d807
# Variable types: 0 continuous, 5960 integer (5944 binary)
# Coefficient statistics:
#   Matrix range     [6e-01, 5e+03]
#   Objective range  [5e+01, 2e+02]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 3550.0000000
# Presolve removed 16 rows and 5408 columns
# Presolve time: 0.00s
# Presolved: 492 rows, 552 columns, 2216 nonzeros
# Variable types: 0 continuous, 552 integer (536 binary)
#
# Root relaxation: objective 1.680682e+03, 576 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1680.68182    0   81 3550.00000 1680.68182  52.7%     -    0s
# H    0     0                    1975.0000000 1680.68182  14.9%     -    0s
# H    0     0                    1950.0000000 1680.68182  13.8%     -    0s
#      0     0 1680.68182    0  116 1950.00000 1680.68182  13.8%     -    0s
#      0     0 1680.68182    0  103 1950.00000 1680.68182  13.8%     -    0s
#      0     0 1680.68182    0   75 1950.00000 1680.68182  13.8%     -    0s
#      0     0 1680.68182    0   75 1950.00000 1680.68182  13.8%     -    0s
#      0     0 1680.68182    0   96 1950.00000 1680.68182  13.8%     -    0s
#      0     0 1680.68182    0   88 1950.00000 1680.68182  13.8%     -    0s
#      0     0 1680.68182    0  105 1950.00000 1680.68182  13.8%     -    0s
#      0     0 1680.68182    0   88 1950.00000 1680.68182  13.8%     -    0s
#      0     2 1680.68182    0   86 1950.00000 1680.68182  13.8%     -    0s
# H  158   137                    1925.0000000 1680.68182  12.7%   144    0s
# H  231   181                    1900.0000000 1680.68182  11.5%   122    0s
# H  610   462                    1875.0000000 1680.68182  10.4%  78.6    0s
# H  625   437                    1850.0000000 1680.68182  9.15%  77.1    0s
# H 1054   527                    1825.0000000 1680.68182  7.91%  72.1    0s
#   6691  1480     cutoff   52      1825.00000 1712.54147  6.16%   104    5s
# H 9830  1538                    1800.0000000 1738.73460  3.40%   102    5s
# H15635   594                    1775.0000000 1775.00000  0.00%   122    7s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 20
#   MIR: 9
#   StrongCG: 8
#   Flow cover: 3
#   Inf proof: 2
#   Zero half: 7
#   RLT: 16
#   Relax-and-lift: 4
#
# Explored 16238 nodes (1966773 simplex iterations) in 7.86 seconds (15.49 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1775 1800 1825 ... 3550
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.775000000000e+03, best bound 1.775000000000e+03, gap 0.0000%
# (i) Updated Optimal Cost with 2x Overtime: $1775.00
#
# Attendant Summary for Updated Model with 2x Overtime Pay:
# Attendant 1: Floors [3, 8], Overtime: 1.00 hours, Total Sqft Cleaned: 3230.00, Floor Violations: 0, Total Wage: $250.00
# Attendant 2: Floors [9, 5], Overtime: 0.00 hours, Total Sqft Cleaned: 3383.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 3: Floors [14, 10], Overtime: 0.00 hours, Total Sqft Cleaned: 2922.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 4: Floors [7, 6], Overtime: 0.00 hours, Total Sqft Cleaned: 2617.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 5: Floors [4, 12], Overtime: 0.00 hours, Total Sqft Cleaned: 3044.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 6: Floors [1, 11], Overtime: 1.00 hours, Total Sqft Cleaned: 3393.00, Floor Violations: 0, Total Wage: $250.00
# Attendant 7: Floors [12, 2], Overtime: 0.00 hours, Total Sqft Cleaned: 2971.00, Floor Violations: 0, Total Wage: $200.00
# Attendant 8: Floors [13, 5], Overtime: 0.00 hours, Total Sqft Cleaned: 3365.00, Floor Violations: 0, Total Wage: $200.00

# %%
print("\n=================== Cost Comparison: Before vs After 2x Overtime ===================")
print(f"{'Metric':<25} {'Before 2x Overtime':<25} {'After 2x Overtime'}")
print("-" * 75)

# Optimal Cost Comparison
print(f"{'Optimal Cost':<25} ${model.objVal:,.2f} {' ' * 10} ${model_i.objVal:,.2f}")

# Overtime Hours Comparison
total_overtime_after = sum(
    round(model_i.getVarByName(f"Overtime[{i}]").x, 2) for i in range(num_attendants)
)
print(f"{'Total Overtime Hours':<25} {total_overtime:.2f} {' ' * 20} {total_overtime_after:.2f}")

# Floor Violation Calculation
total_floor_violations_after = sum(
    max(0, len([k for k in floors if f[i, k].x > 0.5]) - 2) for i in range(num_attendants)
)

# Floor Violations Comparison
print(f"{'Total Floor Violations':<25} {int(total_floor_violations)} {' ' * 23} {int(total_floor_violations_after)}")
# Out:
# =================== Cost Comparison: Before vs After 2x Overtime ===================
# Metric                    Before 2x Overtime        After 2x Overtime
# ---------------------------------------------------------------------------
# Optimal Cost              $1,750.00            $1,775.00
# Total Overtime Hours      4.00                      2.00
# Total Floor Violations    0                         0

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

centers = pd.read_csv('https://raw.githubusercontent.com/mn42899/operations_research/refs/heads/main/centers.csv')
farms = pd.read_csv('https://raw.githubusercontent.com/mn42899/operations_research/refs/heads/main/farms.csv')
processing = pd.read_csv('https://raw.githubusercontent.com/mn42899/operations_research/refs/heads/main/processing.csv')
updated_gym_data = pd.read_csv('https://raw.githubusercontent.com/mn42899/operations_research/refs/heads/main/updated_gym_data.csv')

# %% [markdown]
# 1. b) Using Gurobi, what is the minimum cost of the transportation and procurement plan?

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# Parameters
farm_ids = farms['Farm_ID']
processing_ids = processing['Processing_Plant_ID']
center_ids = centers['Center_ID']

farm_capacity = farms.set_index('Farm_ID')['Bio_Material_Capacity_Tons']
farm_cost = farms.set_index('Farm_ID')['Cost_Per_Ton']

# Extract transport costs from farm to processing
farm_to_processing_cost = farms.set_index('Farm_ID').filter(like="Transport_Cost_To_Plant")

processing_capacity = processing.set_index('Processing_Plant_ID')['Capacity_Tons']
processing_cost = processing.set_index('Processing_Plant_ID')['Processing_Cost_Per_Ton']

# Extract transport costs from processing to centers
processing_to_center_cost = processing.set_index('Processing_Plant_ID').filter(like="Transport_Cost_To_Center")

center_demand = centers.set_index('Center_ID')['Requested_Demand_Tons']

# Create model
model = gp.Model('Transportation_and_Procurement')

# Decision variables
x_fp = model.addVars(farm_ids, processing_ids, name="x_fp", lb=0)  # Raw material from farms to processing
x_pc = model.addVars(processing_ids, center_ids, name="x_pc", lb=0)  # Fertilizer from processing to centers

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x_fp[f, p] * (farm_cost[f] + farm_to_processing_cost.loc[f, f'Transport_Cost_To_Plant_{p.split("_")[-1]}'])
        for f in farm_ids for p in processing_ids
    ) +
    gp.quicksum(
        x_pc[p, c] * (processing_cost[p] + processing_to_center_cost.loc[p, f'Transport_Cost_To_Center_{c.split("_")[-1]}'])
        for p in processing_ids for c in center_ids
    ),
    GRB.MINIMIZE
)

# Constraints
# Farm capacity constraints
for f in farm_ids:
    model.addConstr(gp.quicksum(x_fp[f, p] for p in processing_ids) <= farm_capacity[f], f"FarmCapacity_{f}")

# Processing facility capacity constraints
for p in processing_ids:
    model.addConstr(gp.quicksum(x_fp[f, p] for f in farm_ids) <= processing_capacity[p], f"ProcessingCapacity_{p}")

# Center demand constraints
for c in center_ids:
    model.addConstr(gp.quicksum(x_pc[p, c] for p in processing_ids) == center_demand[c], f"CenterDemand_{c}")

# Flow balance constraints: Input to processing equals output
for p in processing_ids:
    model.addConstr(
        gp.quicksum(x_fp[f, p] for f in farm_ids) == gp.quicksum(x_pc[p, c] for c in center_ids),
        f"FlowBalance_{p}"
    )

# Solve the model
model.optimize()

# Output the results
if model.status == GRB.OPTIMAL:
    # Output the minimum cost
    print("=" * 50)
    print(f"Optimal Transportation and Procurement Cost: ${model.objVal:,.2f}")
    print("=" * 50)

    # Output detailed solution
    print("\nFarm to Processing Assignments:")
    for f in farm_ids:
        for p in processing_ids:
            if x_fp[f, p].x > 0:
                print(f"Farm {f} -> Processing {p}: {x_fp[f, p].x:.2f} tons")

    print("\nProcessing to Center Assignments:")
    for p in processing_ids:
        for c in center_ids:
            if x_pc[p, c].x > 0:
                print(f"Processing {p} -> Center {c}: {x_pc[p, c].x:.2f} tons")

else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 387 rows, 6318 columns and 17118 nonzeros
# Model fingerprint: 0x3aa78cc0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 3e+04]
# Presolve time: 0.00s
# Presolved: 387 rows, 6318 columns, 17118 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9457439e+05   2.902000e+04   0.000000e+00      0s
#      330    2.2970900e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 330 iterations and 0.01 seconds (0.02 work units)
# Optimal objective  2.297089973e+06
# ==================================================
# Optimal Transportation and Procurement Cost: $2,297,089.97
# ==================================================
#
# Farm to Processing Assignments:
# Farm Farm_4 -> Processing Plant_9: 367.00 tons
# Farm Farm_5 -> Processing Plant_6: 499.00 tons
# Farm Farm_6 -> Processing Plant_16: 417.00 tons
# Farm Farm_14 -> Processing Plant_6: 526.00 tons
# Farm Farm_15 -> Processing Plant_9: 441.00 tons
# Farm Farm_26 -> Processing Plant_2: 564.00 tons
# Farm Farm_31 -> Processing Plant_9: 468.00 tons
# Farm Farm_35 -> Processing Plant_1: 476.00 tons
# Farm Farm_36 -> Processing Plant_9: 519.00 tons
# Farm Farm_38 -> Processing Plant_6: 379.00 tons
# Farm Farm_39 -> Processing Plant_1: 489.00 tons
# Farm Farm_43 -> Processing Plant_9: 575.00 tons
# Farm Farm_46 -> Processing Plant_9: 564.00 tons
# Farm Farm_47 -> Processing Plant_16: 552.00 tons
# Farm Farm_52 -> Processing Plant_9: 317.00 tons
# Farm Farm_54 -> Processing Plant_1: 278.00 tons
# Farm Farm_57 -> Processing Plant_9: 306.00 tons
# Farm Farm_62 -> Processing Plant_1: 206.00 tons
# Farm Farm_62 -> Processing Plant_9: 66.00 tons
# Farm Farm_65 -> Processing Plant_16: 225.00 tons
# Farm Farm_66 -> Processing Plant_1: 409.00 tons
# Farm Farm_67 -> Processing Plant_10: 291.00 tons
# Farm Farm_71 -> Processing Plant_1: 508.00 tons
# Farm Farm_73 -> Processing Plant_9: 386.00 tons
# Farm Farm_76 -> Processing Plant_1: 471.00 tons
# Farm Farm_76 -> Processing Plant_16: 76.00 tons
# Farm Farm_85 -> Processing Plant_1: 348.00 tons
# Farm Farm_86 -> Processing Plant_10: 418.00 tons
# Farm Farm_94 -> Processing Plant_2: 239.00 tons
# Farm Farm_94 -> Processing Plant_6: 336.00 tons
# Farm Farm_99 -> Processing Plant_2: 243.00 tons
# Farm Farm_105 -> Processing Plant_9: 522.00 tons
# Farm Farm_107 -> Processing Plant_10: 457.00 tons
# Farm Farm_108 -> Processing Plant_16: 288.00 tons
# Farm Farm_109 -> Processing Plant_10: 122.00 tons
# Farm Farm_109 -> Processing Plant_16: 275.00 tons
# Farm Farm_110 -> Processing Plant_2: 481.00 tons
# Farm Farm_111 -> Processing Plant_9: 399.00 tons
# Farm Farm_121 -> Processing Plant_2: 586.00 tons
# Farm Farm_122 -> Processing Plant_10: 395.00 tons
# Farm Farm_130 -> Processing Plant_9: 538.00 tons
# Farm Farm_131 -> Processing Plant_9: 255.00 tons
# Farm Farm_133 -> Processing Plant_10: 337.00 tons
# Farm Farm_135 -> Processing Plant_16: 533.00 tons
# Farm Farm_141 -> Processing Plant_9: 574.00 tons
# Farm Farm_142 -> Processing Plant_1: 422.00 tons
# Farm Farm_143 -> Processing Plant_9: 398.00 tons
# Farm Farm_145 -> Processing Plant_10: 486.00 tons
# Farm Farm_147 -> Processing Plant_6: 449.00 tons
# Farm Farm_150 -> Processing Plant_10: 247.00 tons
# Farm Farm_151 -> Processing Plant_2: 308.00 tons
# Farm Farm_155 -> Processing Plant_9: 368.00 tons
# Farm Farm_161 -> Processing Plant_9: 472.00 tons
# Farm Farm_165 -> Processing Plant_9: 448.00 tons
# Farm Farm_171 -> Processing Plant_1: 564.00 tons
# Farm Farm_172 -> Processing Plant_6: 289.00 tons
# Farm Farm_183 -> Processing Plant_10: 242.00 tons
# Farm Farm_188 -> Processing Plant_9: 209.00 tons
# Farm Farm_189 -> Processing Plant_2: 495.00 tons
# Farm Farm_192 -> Processing Plant_6: 355.00 tons
# Farm Farm_196 -> Processing Plant_10: 573.00 tons
# Farm Farm_203 -> Processing Plant_6: 519.00 tons
# Farm Farm_204 -> Processing Plant_10: 398.00 tons
# Farm Farm_205 -> Processing Plant_1: 555.00 tons
# Farm Farm_206 -> Processing Plant_1: 313.00 tons
# Farm Farm_210 -> Processing Plant_16: 421.00 tons
# Farm Farm_212 -> Processing Plant_10: 366.00 tons
# Farm Farm_213 -> Processing Plant_1: 406.00 tons
# Farm Farm_218 -> Processing Plant_1: 356.00 tons
# Farm Farm_226 -> Processing Plant_2: 386.00 tons
# Farm Farm_238 -> Processing Plant_6: 269.00 tons
# Farm Farm_240 -> Processing Plant_10: 317.00 tons
# Farm Farm_243 -> Processing Plant_1: 413.00 tons
# Farm Farm_244 -> Processing Plant_2: 255.00 tons
#
# Processing to Center Assignments:
# Processing Plant_1 -> Center Center_7: 480.00 tons
# Processing Plant_1 -> Center Center_8: 149.00 tons
# Processing Plant_1 -> Center Center_10: 469.00 tons
# Processing Plant_1 -> Center Center_15: 320.00 tons
# Processing Plant_1 -> Center Center_18: 437.00 tons
# Processing Plant_1 -> Center Center_20: 258.00 tons
# Processing Plant_1 -> Center Center_21: 327.00 tons
# Processing Plant_1 -> Center Center_23: 127.00 tons
# Processing Plant_1 -> Center Center_40: 150.00 tons
# Processing Plant_1 -> Center Center_41: 474.00 tons
# Processing Plant_1 -> Center Center_49: 105.00 tons
# Processing Plant_1 -> Center Center_52: 336.00 tons
# Processing Plant_1 -> Center Center_54: 490.00 tons
# Processing Plant_1 -> Center Center_58: 122.00 tons
# Processing Plant_1 -> Center Center_61: 315.00 tons
# Processing Plant_1 -> Center Center_70: 112.00 tons
# Processing Plant_1 -> Center Center_79: 371.00 tons
# Processing Plant_1 -> Center Center_81: 370.00 tons
# Processing Plant_1 -> Center Center_85: 342.00 tons
# Processing Plant_1 -> Center Center_90: 168.00 tons
# Processing Plant_1 -> Center Center_96: 292.00 tons
# Processing Plant_2 -> Center Center_1: 82.00 tons
# Processing Plant_2 -> Center Center_12: 267.00 tons
# Processing Plant_2 -> Center Center_14: 147.00 tons
# Processing Plant_2 -> Center Center_36: 183.00 tons
# Processing Plant_2 -> Center Center_37: 245.00 tons
# Processing Plant_2 -> Center Center_38: 439.00 tons
# Processing Plant_2 -> Center Center_47: 486.00 tons
# Processing Plant_2 -> Center Center_55: 228.00 tons
# Processing Plant_2 -> Center Center_62: 496.00 tons
# Processing Plant_2 -> Center Center_74: 211.00 tons
# Processing Plant_2 -> Center Center_84: 443.00 tons
# Processing Plant_2 -> Center Center_86: 225.00 tons
# Processing Plant_2 -> Center Center_89: 105.00 tons
# Processing Plant_6 -> Center Center_3: 464.00 tons
# Processing Plant_6 -> Center Center_24: 450.00 tons
# Processing Plant_6 -> Center Center_26: 147.00 tons
# Processing Plant_6 -> Center Center_32: 129.00 tons
# Processing Plant_6 -> Center Center_35: 277.00 tons
# Processing Plant_6 -> Center Center_45: 132.00 tons
# Processing Plant_6 -> Center Center_46: 476.00 tons
# Processing Plant_6 -> Center Center_59: 264.00 tons
# Processing Plant_6 -> Center Center_68: 68.00 tons
# Processing Plant_6 -> Center Center_75: 292.00 tons
# Processing Plant_6 -> Center Center_76: 194.00 tons
# Processing Plant_6 -> Center Center_80: 484.00 tons
# Processing Plant_6 -> Center Center_88: 118.00 tons
# Processing Plant_6 -> Center Center_101: 126.00 tons
# Processing Plant_9 -> Center Center_2: 348.00 tons
# Processing Plant_9 -> Center Center_5: 340.00 tons
# Processing Plant_9 -> Center Center_6: 86.00 tons
# Processing Plant_9 -> Center Center_11: 473.00 tons
# Processing Plant_9 -> Center Center_19: 455.00 tons
# Processing Plant_9 -> Center Center_22: 255.00 tons
# Processing Plant_9 -> Center Center_25: 377.00 tons
# Processing Plant_9 -> Center Center_27: 395.00 tons
# Processing Plant_9 -> Center Center_30: 385.00 tons
# Processing Plant_9 -> Center Center_31: 143.00 tons
# Processing Plant_9 -> Center Center_33: 87.00 tons
# Processing Plant_9 -> Center Center_39: 331.00 tons
# Processing Plant_9 -> Center Center_43: 343.00 tons
# Processing Plant_9 -> Center Center_51: 489.00 tons
# Processing Plant_9 -> Center Center_53: 260.00 tons
# Processing Plant_9 -> Center Center_56: 457.00 tons
# Processing Plant_9 -> Center Center_60: 437.00 tons
# Processing Plant_9 -> Center Center_65: 403.00 tons
# Processing Plant_9 -> Center Center_66: 283.00 tons
# Processing Plant_9 -> Center Center_69: 162.00 tons
# Processing Plant_9 -> Center Center_78: 130.00 tons
# Processing Plant_9 -> Center Center_83: 362.00 tons
# Processing Plant_9 -> Center Center_87: 425.00 tons
# Processing Plant_9 -> Center Center_92: 469.00 tons
# Processing Plant_9 -> Center Center_94: 104.00 tons
# Processing Plant_9 -> Center Center_100: 193.00 tons
# Processing Plant_10 -> Center Center_4: 161.00 tons
# Processing Plant_10 -> Center Center_13: 138.00 tons
# Processing Plant_10 -> Center Center_17: 286.00 tons
# Processing Plant_10 -> Center Center_28: 414.00 tons
# Processing Plant_10 -> Center Center_29: 399.00 tons
# Processing Plant_10 -> Center Center_34: 457.00 tons
# Processing Plant_10 -> Center Center_42: 124.00 tons
# Processing Plant_10 -> Center Center_44: 257.00 tons
# Processing Plant_10 -> Center Center_48: 192.00 tons
# Processing Plant_10 -> Center Center_50: 410.00 tons
# Processing Plant_10 -> Center Center_64: 320.00 tons
# Processing Plant_10 -> Center Center_67: 368.00 tons
# Processing Plant_10 -> Center Center_73: 326.00 tons
# Processing Plant_10 -> Center Center_77: 195.00 tons
# Processing Plant_10 -> Center Center_91: 253.00 tons
# Processing Plant_10 -> Center Center_98: 285.00 tons
# Processing Plant_10 -> Center Center_99: 64.00 tons
# Processing Plant_16 -> Center Center_9: 72.00 tons
# Processing Plant_16 -> Center Center_14: 111.00 tons
# Processing Plant_16 -> Center Center_16: 470.00 tons
# Processing Plant_16 -> Center Center_57: 107.00 tons
# Processing Plant_16 -> Center Center_63: 122.00 tons
# Processing Plant_16 -> Center Center_71: 421.00 tons
# Processing Plant_16 -> Center Center_72: 233.00 tons
# Processing Plant_16 -> Center Center_82: 92.00 tons
# Processing Plant_16 -> Center Center_93: 464.00 tons
# Processing Plant_16 -> Center Center_95: 87.00 tons
# Processing Plant_16 -> Center Center_97: 250.00 tons
# Processing Plant_16 -> Center Center_102: 358.00 tons

# %% [markdown]
# 1. c) If the processing plants of the raw material are restricted to only send fertilizer to home centers
# within the same region of the US, what is the optimal cost?

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# Parameters
farm_ids = farms['Farm_ID']
processing_ids = processing['Processing_Plant_ID']
center_ids = centers['Center_ID']

farm_capacity = farms.set_index('Farm_ID')['Bio_Material_Capacity_Tons']
farm_cost = farms.set_index('Farm_ID')['Cost_Per_Ton']

# Extract transport costs from farm to processing
farm_to_processing_cost = farms.set_index('Farm_ID').filter(like="Transport_Cost_To_Plant")

processing_capacity = processing.set_index('Processing_Plant_ID')['Capacity_Tons']
processing_cost = processing.set_index('Processing_Plant_ID')['Processing_Cost_Per_Ton']

# Extract transport costs from processing to centers
processing_to_center_cost = processing.set_index('Processing_Plant_ID').filter(like="Transport_Cost_To_Center")

center_demand = centers.set_index('Center_ID')['Requested_Demand_Tons']

# Extract regions
processing_regions = processing.set_index('Processing_Plant_ID')['Region']
center_regions = centers.set_index('Center_ID')['Region']

# Create model
model = gp.Model('Transportation_and_Procurement_Regional')

# Decision variables
x_fp = model.addVars(farm_ids, processing_ids, name="x_fp", lb=0)  # Raw material from farms to processing
x_pc = model.addVars(processing_ids, center_ids, name="x_pc", lb=0)  # Fertilizer from processing to centers

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x_fp[f, p] * (farm_cost[f] + farm_to_processing_cost.loc[f, f'Transport_Cost_To_Plant_{p.split("_")[-1]}'])
        for f in farm_ids for p in processing_ids
    ) +
    gp.quicksum(
        x_pc[p, c] * (processing_cost[p] + processing_to_center_cost.loc[p, f'Transport_Cost_To_Center_{c.split("_")[-1]}'])
        for p in processing_ids for c in center_ids
    ),
    GRB.MINIMIZE
)

# Constraints
# Farm capacity constraints
for f in farm_ids:
    model.addConstr(gp.quicksum(x_fp[f, p] for p in processing_ids) <= farm_capacity[f], f"FarmCapacity_{f}")

# Processing facility capacity constraints
for p in processing_ids:
    model.addConstr(gp.quicksum(x_fp[f, p] for f in farm_ids) <= processing_capacity[p], f"ProcessingCapacity_{p}")

# Center demand constraints
for c in center_ids:
    model.addConstr(gp.quicksum(x_pc[p, c] for p in processing_ids) == center_demand[c], f"CenterDemand_{c}")

# Flow balance constraints: Input to processing equals output
for p in processing_ids:
    model.addConstr(
        gp.quicksum(x_fp[f, p] for f in farm_ids) == gp.quicksum(x_pc[p, c] for c in center_ids),
        f"FlowBalance_{p}"
    )

# Regional constraints: Processing plants can only send to centers in the same region
for p in processing_ids:
    for c in center_ids:
        if processing_regions[p] != center_regions[c]:
            model.addConstr(x_pc[p, c] == 0, f"RegionalConstraint_{p}_{c}")

# Solve the model
model.optimize()

# Output the results
if model.status == GRB.OPTIMAL:
    # Output the minimum cost
    print("=" * 50)
    print(f"Optimal Transportation and Procurement Cost (Regional): ${model.objVal:,.2f}")
    print("=" * 50)

    # Output detailed solution
    print("\nFarm to Processing Assignments:")
    for f in farm_ids:
        for p in processing_ids:
            if x_fp[f, p].x > 0:
                print(f"Farm {f} -> Processing {p}: {x_fp[f, p].x:.2f} tons")

    print("\nProcessing to Center Assignments:")
    for p in processing_ids:
        for c in center_ids:
            if x_pc[p, c].x > 0:
                print(f"Processing {p} -> Center {c}: {x_pc[p, c].x:.2f} tons")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1761 rows, 6318 columns and 18492 nonzeros
# Model fingerprint: 0x9c296277
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 3e+04]
# Presolve removed 1374 rows and 1374 columns
# Presolve time: 0.01s
# Presolved: 387 rows, 4944 columns, 14370 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2479485e+05   3.627500e+03   0.000000e+00      0s
#      320    2.3234885e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 320 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.323488497e+06
# ==================================================
# Optimal Transportation and Procurement Cost (Regional): $2,323,488.50
# ==================================================
#
# Farm to Processing Assignments:
# Farm Farm_4 -> Processing Plant_9: 367.00 tons
# Farm Farm_5 -> Processing Plant_6: 499.00 tons
# Farm Farm_6 -> Processing Plant_13: 417.00 tons
# Farm Farm_14 -> Processing Plant_13: 526.00 tons
# Farm Farm_15 -> Processing Plant_16: 441.00 tons
# Farm Farm_26 -> Processing Plant_1: 564.00 tons
# Farm Farm_31 -> Processing Plant_9: 468.00 tons
# Farm Farm_35 -> Processing Plant_16: 476.00 tons
# Farm Farm_36 -> Processing Plant_10: 519.00 tons
# Farm Farm_38 -> Processing Plant_18: 379.00 tons
# Farm Farm_39 -> Processing Plant_1: 489.00 tons
# Farm Farm_43 -> Processing Plant_16: 575.00 tons
# Farm Farm_46 -> Processing Plant_18: 564.00 tons
# Farm Farm_47 -> Processing Plant_16: 552.00 tons
# Farm Farm_52 -> Processing Plant_9: 317.00 tons
# Farm Farm_54 -> Processing Plant_1: 278.00 tons
# Farm Farm_57 -> Processing Plant_4: 156.00 tons
# Farm Farm_57 -> Processing Plant_9: 150.00 tons
# Farm Farm_62 -> Processing Plant_16: 272.00 tons
# Farm Farm_65 -> Processing Plant_16: 225.00 tons
# Farm Farm_66 -> Processing Plant_1: 241.00 tons
# Farm Farm_66 -> Processing Plant_10: 168.00 tons
# Farm Farm_67 -> Processing Plant_10: 291.00 tons
# Farm Farm_71 -> Processing Plant_1: 340.00 tons
# Farm Farm_71 -> Processing Plant_17: 168.00 tons
# Farm Farm_73 -> Processing Plant_9: 386.00 tons
# Farm Farm_76 -> Processing Plant_13: 547.00 tons
# Farm Farm_85 -> Processing Plant_1: 348.00 tons
# Farm Farm_86 -> Processing Plant_16: 418.00 tons
# Farm Farm_94 -> Processing Plant_6: 575.00 tons
# Farm Farm_99 -> Processing Plant_2: 243.00 tons
# Farm Farm_105 -> Processing Plant_18: 522.00 tons
# Farm Farm_107 -> Processing Plant_10: 457.00 tons
# Farm Farm_108 -> Processing Plant_16: 288.00 tons
# Farm Farm_109 -> Processing Plant_16: 397.00 tons
# Farm Farm_110 -> Processing Plant_2: 481.00 tons
# Farm Farm_111 -> Processing Plant_1: 399.00 tons
# Farm Farm_121 -> Processing Plant_2: 586.00 tons
# Farm Farm_122 -> Processing Plant_10: 395.00 tons
# Farm Farm_130 -> Processing Plant_17: 538.00 tons
# Farm Farm_131 -> Processing Plant_9: 197.00 tons
# Farm Farm_131 -> Processing Plant_17: 58.00 tons
# Farm Farm_133 -> Processing Plant_10: 337.00 tons
# Farm Farm_135 -> Processing Plant_16: 533.00 tons
# Farm Farm_141 -> Processing Plant_9: 574.00 tons
# Farm Farm_142 -> Processing Plant_18: 422.00 tons
# Farm Farm_143 -> Processing Plant_13: 398.00 tons
# Farm Farm_145 -> Processing Plant_16: 486.00 tons
# Farm Farm_147 -> Processing Plant_5: 449.00 tons
# Farm Farm_150 -> Processing Plant_4: 247.00 tons
# Farm Farm_151 -> Processing Plant_5: 6.00 tons
# Farm Farm_151 -> Processing Plant_6: 23.00 tons
# Farm Farm_151 -> Processing Plant_10: 279.00 tons
# Farm Farm_155 -> Processing Plant_1: 368.00 tons
# Farm Farm_161 -> Processing Plant_13: 472.00 tons
# Farm Farm_165 -> Processing Plant_10: 448.00 tons
# Farm Farm_171 -> Processing Plant_1: 564.00 tons
# Farm Farm_172 -> Processing Plant_18: 289.00 tons
# Farm Farm_183 -> Processing Plant_13: 242.00 tons
# Farm Farm_188 -> Processing Plant_10: 209.00 tons
# Farm Farm_189 -> Processing Plant_2: 495.00 tons
# Farm Farm_192 -> Processing Plant_6: 281.00 tons
# Farm Farm_192 -> Processing Plant_16: 74.00 tons
# Farm Farm_196 -> Processing Plant_10: 573.00 tons
# Farm Farm_203 -> Processing Plant_17: 519.00 tons
# Farm Farm_204 -> Processing Plant_13: 398.00 tons
# Farm Farm_205 -> Processing Plant_4: 555.00 tons
# Farm Farm_206 -> Processing Plant_1: 313.00 tons
# Farm Farm_210 -> Processing Plant_16: 421.00 tons
# Farm Farm_212 -> Processing Plant_10: 366.00 tons
# Farm Farm_213 -> Processing Plant_1: 406.00 tons
# Farm Farm_218 -> Processing Plant_18: 356.00 tons
# Farm Farm_226 -> Processing Plant_2: 343.00 tons
# Farm Farm_226 -> Processing Plant_16: 43.00 tons
# Farm Farm_238 -> Processing Plant_13: 269.00 tons
# Farm Farm_240 -> Processing Plant_10: 317.00 tons
# Farm Farm_243 -> Processing Plant_1: 413.00 tons
# Farm Farm_244 -> Processing Plant_18: 255.00 tons
#
# Processing to Center Assignments:
# Processing Plant_1 -> Center Center_2: 348.00 tons
# Processing Plant_1 -> Center Center_7: 480.00 tons
# Processing Plant_1 -> Center Center_14: 258.00 tons
# Processing Plant_1 -> Center Center_15: 320.00 tons
# Processing Plant_1 -> Center Center_33: 87.00 tons
# Processing Plant_1 -> Center Center_46: 476.00 tons
# Processing Plant_1 -> Center Center_52: 336.00 tons
# Processing Plant_1 -> Center Center_58: 122.00 tons
# Processing Plant_1 -> Center Center_65: 403.00 tons
# Processing Plant_1 -> Center Center_72: 233.00 tons
# Processing Plant_1 -> Center Center_74: 211.00 tons
# Processing Plant_1 -> Center Center_75: 292.00 tons
# Processing Plant_1 -> Center Center_78: 130.00 tons
# Processing Plant_1 -> Center Center_79: 371.00 tons
# Processing Plant_1 -> Center Center_82: 92.00 tons
# Processing Plant_1 -> Center Center_90: 168.00 tons
# Processing Plant_1 -> Center Center_94: 104.00 tons
# Processing Plant_1 -> Center Center_96: 292.00 tons
# Processing Plant_2 -> Center Center_23: 127.00 tons
# Processing Plant_2 -> Center Center_37: 245.00 tons
# Processing Plant_2 -> Center Center_47: 486.00 tons
# Processing Plant_2 -> Center Center_62: 496.00 tons
# Processing Plant_2 -> Center Center_63: 122.00 tons
# Processing Plant_2 -> Center Center_85: 342.00 tons
# Processing Plant_2 -> Center Center_86: 225.00 tons
# Processing Plant_2 -> Center Center_89: 105.00 tons
# Processing Plant_4 -> Center Center_20: 258.00 tons
# Processing Plant_4 -> Center Center_44: 257.00 tons
# Processing Plant_4 -> Center Center_84: 443.00 tons
# Processing Plant_5 -> Center Center_19: 455.00 tons
# Processing Plant_6 -> Center Center_3: 464.00 tons
# Processing Plant_6 -> Center Center_40: 150.00 tons
# Processing Plant_6 -> Center Center_42: 124.00 tons
# Processing Plant_6 -> Center Center_61: 315.00 tons
# Processing Plant_6 -> Center Center_70: 112.00 tons
# Processing Plant_6 -> Center Center_95: 87.00 tons
# Processing Plant_6 -> Center Center_101: 126.00 tons
# Processing Plant_9 -> Center Center_10: 469.00 tons
# Processing Plant_9 -> Center Center_21: 327.00 tons
# Processing Plant_9 -> Center Center_27: 395.00 tons
# Processing Plant_9 -> Center Center_43: 343.00 tons
# Processing Plant_9 -> Center Center_81: 370.00 tons
# Processing Plant_9 -> Center Center_83: 362.00 tons
# Processing Plant_9 -> Center Center_100: 193.00 tons
# Processing Plant_10 -> Center Center_4: 161.00 tons
# Processing Plant_10 -> Center Center_17: 286.00 tons
# Processing Plant_10 -> Center Center_25: 377.00 tons
# Processing Plant_10 -> Center Center_26: 147.00 tons
# Processing Plant_10 -> Center Center_31: 143.00 tons
# Processing Plant_10 -> Center Center_34: 457.00 tons
# Processing Plant_10 -> Center Center_35: 277.00 tons
# Processing Plant_10 -> Center Center_45: 132.00 tons
# Processing Plant_10 -> Center Center_51: 489.00 tons
# Processing Plant_10 -> Center Center_60: 437.00 tons
# Processing Plant_10 -> Center Center_67: 368.00 tons
# Processing Plant_10 -> Center Center_88: 118.00 tons
# Processing Plant_10 -> Center Center_91: 253.00 tons
# Processing Plant_10 -> Center Center_93: 464.00 tons
# Processing Plant_10 -> Center Center_97: 250.00 tons
# Processing Plant_13 -> Center Center_11: 376.00 tons
# Processing Plant_13 -> Center Center_28: 414.00 tons
# Processing Plant_13 -> Center Center_50: 410.00 tons
# Processing Plant_13 -> Center Center_53: 260.00 tons
# Processing Plant_13 -> Center Center_54: 490.00 tons
# Processing Plant_13 -> Center Center_59: 264.00 tons
# Processing Plant_13 -> Center Center_66: 283.00 tons
# Processing Plant_13 -> Center Center_69: 162.00 tons
# Processing Plant_13 -> Center Center_77: 141.00 tons
# Processing Plant_13 -> Center Center_92: 469.00 tons
# Processing Plant_16 -> Center Center_1: 82.00 tons
# Processing Plant_16 -> Center Center_5: 340.00 tons
# Processing Plant_16 -> Center Center_6: 86.00 tons
# Processing Plant_16 -> Center Center_8: 149.00 tons
# Processing Plant_16 -> Center Center_16: 470.00 tons
# Processing Plant_16 -> Center Center_18: 437.00 tons
# Processing Plant_16 -> Center Center_22: 255.00 tons
# Processing Plant_16 -> Center Center_24: 450.00 tons
# Processing Plant_16 -> Center Center_30: 385.00 tons
# Processing Plant_16 -> Center Center_36: 183.00 tons
# Processing Plant_16 -> Center Center_38: 439.00 tons
# Processing Plant_16 -> Center Center_48: 192.00 tons
# Processing Plant_16 -> Center Center_55: 228.00 tons
# Processing Plant_16 -> Center Center_57: 107.00 tons
# Processing Plant_16 -> Center Center_68: 68.00 tons
# Processing Plant_16 -> Center Center_71: 421.00 tons
# Processing Plant_16 -> Center Center_80: 484.00 tons
# Processing Plant_16 -> Center Center_87: 425.00 tons
# Processing Plant_17 -> Center Center_32: 129.00 tons
# Processing Plant_17 -> Center Center_41: 474.00 tons
# Processing Plant_17 -> Center Center_49: 105.00 tons
# Processing Plant_17 -> Center Center_56: 457.00 tons
# Processing Plant_17 -> Center Center_77: 54.00 tons
# Processing Plant_17 -> Center Center_99: 64.00 tons
# Processing Plant_18 -> Center Center_9: 72.00 tons
# Processing Plant_18 -> Center Center_11: 97.00 tons
# Processing Plant_18 -> Center Center_12: 267.00 tons
# Processing Plant_18 -> Center Center_13: 138.00 tons
# Processing Plant_18 -> Center Center_29: 399.00 tons
# Processing Plant_18 -> Center Center_39: 331.00 tons
# Processing Plant_18 -> Center Center_64: 320.00 tons
# Processing Plant_18 -> Center Center_73: 326.00 tons
# Processing Plant_18 -> Center Center_76: 194.00 tons
# Processing Plant_18 -> Center Center_98: 285.00 tons
# Processing Plant_18 -> Center Center_102: 358.00 tons

# %% [markdown]
# 1. d) If only the highest quality raw material (i.e., levels 3 and 4) is sourced from farms to make fertilizer, what is the optimal cost?

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# Parameters
farm_ids = farms['Farm_ID']
processing_ids = processing['Processing_Plant_ID']
center_ids = centers['Center_ID']

farm_capacity = farms.set_index('Farm_ID')['Bio_Material_Capacity_Tons']
farm_cost = farms.set_index('Farm_ID')['Cost_Per_Ton']
farm_quality = farms.set_index('Farm_ID')['Quality']  # Add quality column

# Extract transport costs from farm to processing
farm_to_processing_cost = farms.set_index('Farm_ID').filter(like="Transport_Cost_To_Plant")

processing_capacity = processing.set_index('Processing_Plant_ID')['Capacity_Tons']
processing_cost = processing.set_index('Processing_Plant_ID')['Processing_Cost_Per_Ton']

# Extract transport costs from processing to centers
processing_to_center_cost = processing.set_index('Processing_Plant_ID').filter(like="Transport_Cost_To_Center")

center_demand = centers.set_index('Center_ID')['Requested_Demand_Tons']

# Create model
model = gp.Model('Transportation_and_Procurement_HighQuality')

# Decision variables
x_fp = model.addVars(farm_ids, processing_ids, name="x_fp", lb=0)  # Raw material from farms to processing
x_pc = model.addVars(processing_ids, center_ids, name="x_pc", lb=0)  # Fertilizer from processing to centers

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x_fp[f, p] * (farm_cost[f] + farm_to_processing_cost.loc[f, f'Transport_Cost_To_Plant_{p.split("_")[-1]}'])
        for f in farm_ids for p in processing_ids
    ) +
    gp.quicksum(
        x_pc[p, c] * (processing_cost[p] + processing_to_center_cost.loc[p, f'Transport_Cost_To_Center_{c.split("_")[-1]}'])
        for p in processing_ids for c in center_ids
    ),
    GRB.MINIMIZE
)

# Constraints
# Farm capacity constraints
for f in farm_ids:
    model.addConstr(gp.quicksum(x_fp[f, p] for p in processing_ids) <= farm_capacity[f], f"FarmCapacity_{f}")

# Processing facility capacity constraints
for p in processing_ids:
    model.addConstr(gp.quicksum(x_fp[f, p] for f in farm_ids) <= processing_capacity[p], f"ProcessingCapacity_{p}")

# Center demand constraints
for c in center_ids:
    model.addConstr(gp.quicksum(x_pc[p, c] for p in processing_ids) == center_demand[c], f"CenterDemand_{c}")

# Flow balance constraints: Input to processing equals output
for p in processing_ids:
    model.addConstr(
        gp.quicksum(x_fp[f, p] for f in farm_ids) == gp.quicksum(x_pc[p, c] for c in center_ids),
        f"FlowBalance_{p}"
    )

# Quality-based constraints: Only farms with quality levels 3 or 4 can supply raw materials
for f in farm_ids:
    if farm_quality[f] < 3:  # Exclude farms with quality less than 3
        for p in processing_ids:
            model.addConstr(x_fp[f, p] == 0, f"QualityConstraint_{f}")

# Solve the model
model.optimize()

# Output the results
if model.status == GRB.OPTIMAL:
    # Output the minimum cost
    print("=" * 50)
    print(f"Optimal Transportation and Procurement Cost (High Quality): ${model.objVal:,.2f}")
    print("=" * 50)

    # Output detailed solution
    print("\nFarm to Processing Assignments:")
    for f in farm_ids:
        for p in processing_ids:
            if x_fp[f, p].x > 0:
                print(f"Farm {f} -> Processing {p}: {x_fp[f, p].x:.2f} tons")

    print("\nProcessing to Center Assignments:")
    for p in processing_ids:
        for c in center_ids:
            if x_pc[p, c].x > 0:
                print(f"Processing {p} -> Center {c}: {x_pc[p, c].x:.2f} tons")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3519 rows, 6318 columns and 20250 nonzeros
# Model fingerprint: 0xa45bebf3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 3e+04]
# Presolve removed 3306 rows and 3132 columns
# Presolve time: 0.01s
# Presolved: 213 rows, 3186 columns, 7722 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9457439e+05   3.627500e+03   0.000000e+00      0s
#      253    5.7129767e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 253 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  5.712976673e+06
# ==================================================
# Optimal Transportation and Procurement Cost (High Quality): $5,712,976.67
# ==================================================
#
# Farm to Processing Assignments:
# Farm Farm_3 -> Processing Plant_10: 516.00 tons
# Farm Farm_11 -> Processing Plant_16: 256.00 tons
# Farm Farm_12 -> Processing Plant_9: 261.00 tons
# Farm Farm_16 -> Processing Plant_9: 289.00 tons
# Farm Farm_18 -> Processing Plant_10: 525.00 tons
# Farm Farm_19 -> Processing Plant_10: 229.00 tons
# Farm Farm_20 -> Processing Plant_6: 558.00 tons
# Farm Farm_21 -> Processing Plant_9: 487.00 tons
# Farm Farm_24 -> Processing Plant_6: 434.00 tons
# Farm Farm_29 -> Processing Plant_9: 526.00 tons
# Farm Farm_32 -> Processing Plant_9: 108.00 tons
# Farm Farm_33 -> Processing Plant_9: 330.00 tons
# Farm Farm_40 -> Processing Plant_10: 576.00 tons
# Farm Farm_45 -> Processing Plant_1: 461.00 tons
# Farm Farm_49 -> Processing Plant_10: 282.00 tons
# Farm Farm_53 -> Processing Plant_9: 391.00 tons
# Farm Farm_58 -> Processing Plant_16: 581.00 tons
# Farm Farm_59 -> Processing Plant_2: 470.00 tons
# Farm Farm_68 -> Processing Plant_1: 324.00 tons
# Farm Farm_69 -> Processing Plant_10: 272.00 tons
# Farm Farm_70 -> Processing Plant_9: 322.00 tons
# Farm Farm_72 -> Processing Plant_9: 383.00 tons
# Farm Farm_75 -> Processing Plant_10: 277.00 tons
# Farm Farm_82 -> Processing Plant_9: 275.00 tons
# Farm Farm_87 -> Processing Plant_1: 321.00 tons
# Farm Farm_91 -> Processing Plant_10: 372.00 tons
# Farm Farm_92 -> Processing Plant_9: 355.00 tons
# Farm Farm_98 -> Processing Plant_10: 267.00 tons
# Farm Farm_100 -> Processing Plant_10: 260.00 tons
# Farm Farm_115 -> Processing Plant_2: 345.00 tons
# Farm Farm_116 -> Processing Plant_9: 381.00 tons
# Farm Farm_120 -> Processing Plant_10: 558.00 tons
# Farm Farm_123 -> Processing Plant_9: 496.00 tons
# Farm Farm_128 -> Processing Plant_1: 237.00 tons
# Farm Farm_129 -> Processing Plant_2: 313.00 tons
# Farm Farm_149 -> Processing Plant_6: 222.00 tons
# Farm Farm_160 -> Processing Plant_1: 512.00 tons
# Farm Farm_162 -> Processing Plant_1: 443.00 tons
# Farm Farm_163 -> Processing Plant_9: 526.00 tons
# Farm Farm_167 -> Processing Plant_1: 309.00 tons
# Farm Farm_168 -> Processing Plant_2: 212.00 tons
# Farm Farm_170 -> Processing Plant_6: 579.00 tons
# Farm Farm_173 -> Processing Plant_9: 541.00 tons
# Farm Farm_174 -> Processing Plant_2: 261.00 tons
# Farm Farm_174 -> Processing Plant_10: 286.00 tons
# Farm Farm_176 -> Processing Plant_2: 420.00 tons
# Farm Farm_177 -> Processing Plant_2: 272.00 tons
# Farm Farm_178 -> Processing Plant_1: 433.00 tons
# Farm Farm_179 -> Processing Plant_1: 459.00 tons
# Farm Farm_180 -> Processing Plant_10: 312.00 tons
# Farm Farm_182 -> Processing Plant_10: 473.00 tons
# Farm Farm_184 -> Processing Plant_9: 407.00 tons
# Farm Farm_190 -> Processing Plant_9: 386.00 tons
# Farm Farm_191 -> Processing Plant_16: 230.00 tons
# Farm Farm_193 -> Processing Plant_10: 259.00 tons
# Farm Farm_194 -> Processing Plant_1: 448.00 tons
# Farm Farm_197 -> Processing Plant_1: 81.00 tons
# Farm Farm_197 -> Processing Plant_16: 388.00 tons
# Farm Farm_199 -> Processing Plant_9: 598.00 tons
# Farm Farm_200 -> Processing Plant_1: 201.00 tons
# Farm Farm_201 -> Processing Plant_1: 223.00 tons
# Farm Farm_209 -> Processing Plant_1: 364.00 tons
# Farm Farm_215 -> Processing Plant_10: 264.00 tons
# Farm Farm_217 -> Processing Plant_16: 203.00 tons
# Farm Farm_219 -> Processing Plant_1: 448.00 tons
# Farm Farm_220 -> Processing Plant_2: 253.00 tons
# Farm Farm_220 -> Processing Plant_6: 203.00 tons
# Farm Farm_221 -> Processing Plant_6: 434.00 tons
# Farm Farm_222 -> Processing Plant_2: 505.00 tons
# Farm Farm_223 -> Processing Plant_9: 565.00 tons
# Farm Farm_224 -> Processing Plant_6: 22.00 tons
# Farm Farm_224 -> Processing Plant_16: 572.00 tons
# Farm Farm_231 -> Processing Plant_6: 310.00 tons
# Farm Farm_232 -> Processing Plant_9: 417.00 tons
# Farm Farm_235 -> Processing Plant_10: 340.00 tons
# Farm Farm_237 -> Processing Plant_6: 338.00 tons
# Farm Farm_241 -> Processing Plant_1: 397.00 tons
# Farm Farm_246 -> Processing Plant_16: 492.00 tons
# Farm Farm_247 -> Processing Plant_6: 374.00 tons
#
# Processing to Center Assignments:
# Processing Plant_1 -> Center Center_7: 480.00 tons
# Processing Plant_1 -> Center Center_8: 149.00 tons
# Processing Plant_1 -> Center Center_15: 320.00 tons
# Processing Plant_1 -> Center Center_18: 437.00 tons
# Processing Plant_1 -> Center Center_20: 258.00 tons
# Processing Plant_1 -> Center Center_21: 327.00 tons
# Processing Plant_1 -> Center Center_40: 150.00 tons
# Processing Plant_1 -> Center Center_41: 474.00 tons
# Processing Plant_1 -> Center Center_52: 336.00 tons
# Processing Plant_1 -> Center Center_54: 490.00 tons
# Processing Plant_1 -> Center Center_56: 148.00 tons
# Processing Plant_1 -> Center Center_58: 122.00 tons
# Processing Plant_1 -> Center Center_61: 315.00 tons
# Processing Plant_1 -> Center Center_70: 112.00 tons
# Processing Plant_1 -> Center Center_79: 371.00 tons
# Processing Plant_1 -> Center Center_81: 370.00 tons
# Processing Plant_1 -> Center Center_85: 342.00 tons
# Processing Plant_1 -> Center Center_90: 168.00 tons
# Processing Plant_1 -> Center Center_96: 292.00 tons
# Processing Plant_2 -> Center Center_1: 82.00 tons
# Processing Plant_2 -> Center Center_12: 267.00 tons
# Processing Plant_2 -> Center Center_23: 127.00 tons
# Processing Plant_2 -> Center Center_36: 183.00 tons
# Processing Plant_2 -> Center Center_37: 245.00 tons
# Processing Plant_2 -> Center Center_38: 439.00 tons
# Processing Plant_2 -> Center Center_55: 228.00 tons
# Processing Plant_2 -> Center Center_62: 496.00 tons
# Processing Plant_2 -> Center Center_74: 211.00 tons
# Processing Plant_2 -> Center Center_84: 443.00 tons
# Processing Plant_2 -> Center Center_86: 225.00 tons
# Processing Plant_2 -> Center Center_89: 105.00 tons
# Processing Plant_6 -> Center Center_3: 464.00 tons
# Processing Plant_6 -> Center Center_24: 450.00 tons
# Processing Plant_6 -> Center Center_32: 129.00 tons
# Processing Plant_6 -> Center Center_35: 277.00 tons
# Processing Plant_6 -> Center Center_45: 132.00 tons
# Processing Plant_6 -> Center Center_46: 476.00 tons
# Processing Plant_6 -> Center Center_59: 264.00 tons
# Processing Plant_6 -> Center Center_68: 68.00 tons
# Processing Plant_6 -> Center Center_75: 292.00 tons
# Processing Plant_6 -> Center Center_76: 194.00 tons
# Processing Plant_6 -> Center Center_80: 484.00 tons
# Processing Plant_6 -> Center Center_88: 118.00 tons
# Processing Plant_6 -> Center Center_101: 126.00 tons
# Processing Plant_9 -> Center Center_2: 348.00 tons
# Processing Plant_9 -> Center Center_5: 340.00 tons
# Processing Plant_9 -> Center Center_6: 86.00 tons
# Processing Plant_9 -> Center Center_11: 473.00 tons
# Processing Plant_9 -> Center Center_19: 455.00 tons
# Processing Plant_9 -> Center Center_22: 255.00 tons
# Processing Plant_9 -> Center Center_25: 377.00 tons
# Processing Plant_9 -> Center Center_27: 395.00 tons
# Processing Plant_9 -> Center Center_30: 385.00 tons
# Processing Plant_9 -> Center Center_31: 143.00 tons
# Processing Plant_9 -> Center Center_33: 87.00 tons
# Processing Plant_9 -> Center Center_39: 331.00 tons
# Processing Plant_9 -> Center Center_43: 343.00 tons
# Processing Plant_9 -> Center Center_51: 489.00 tons
# Processing Plant_9 -> Center Center_53: 260.00 tons
# Processing Plant_9 -> Center Center_56: 309.00 tons
# Processing Plant_9 -> Center Center_60: 437.00 tons
# Processing Plant_9 -> Center Center_65: 403.00 tons
# Processing Plant_9 -> Center Center_66: 283.00 tons
# Processing Plant_9 -> Center Center_69: 162.00 tons
# Processing Plant_9 -> Center Center_78: 130.00 tons
# Processing Plant_9 -> Center Center_83: 362.00 tons
# Processing Plant_9 -> Center Center_87: 425.00 tons
# Processing Plant_9 -> Center Center_92: 469.00 tons
# Processing Plant_9 -> Center Center_94: 104.00 tons
# Processing Plant_9 -> Center Center_100: 193.00 tons
# Processing Plant_10 -> Center Center_4: 161.00 tons
# Processing Plant_10 -> Center Center_10: 469.00 tons
# Processing Plant_10 -> Center Center_13: 138.00 tons
# Processing Plant_10 -> Center Center_17: 286.00 tons
# Processing Plant_10 -> Center Center_28: 414.00 tons
# Processing Plant_10 -> Center Center_29: 399.00 tons
# Processing Plant_10 -> Center Center_34: 457.00 tons
# Processing Plant_10 -> Center Center_42: 124.00 tons
# Processing Plant_10 -> Center Center_44: 257.00 tons
# Processing Plant_10 -> Center Center_47: 486.00 tons
# Processing Plant_10 -> Center Center_48: 192.00 tons
# Processing Plant_10 -> Center Center_50: 410.00 tons
# Processing Plant_10 -> Center Center_64: 320.00 tons
# Processing Plant_10 -> Center Center_67: 368.00 tons
# Processing Plant_10 -> Center Center_73: 326.00 tons
# Processing Plant_10 -> Center Center_77: 195.00 tons
# Processing Plant_10 -> Center Center_91: 253.00 tons
# Processing Plant_10 -> Center Center_93: 464.00 tons
# Processing Plant_10 -> Center Center_98: 285.00 tons
# Processing Plant_10 -> Center Center_99: 64.00 tons
# Processing Plant_16 -> Center Center_9: 72.00 tons
# Processing Plant_16 -> Center Center_14: 258.00 tons
# Processing Plant_16 -> Center Center_16: 470.00 tons
# Processing Plant_16 -> Center Center_26: 147.00 tons
# Processing Plant_16 -> Center Center_49: 105.00 tons
# Processing Plant_16 -> Center Center_57: 107.00 tons
# Processing Plant_16 -> Center Center_63: 122.00 tons
# Processing Plant_16 -> Center Center_71: 421.00 tons
# Processing Plant_16 -> Center Center_72: 233.00 tons
# Processing Plant_16 -> Center Center_82: 92.00 tons
# Processing Plant_16 -> Center Center_95: 87.00 tons
# Processing Plant_16 -> Center Center_97: 250.00 tons
# Processing Plant_16 -> Center Center_102: 358.00 tons

# %% [markdown]
# 1. e) If each facility is limited to processing no more than 3% of all raw material sourced from farms (as a sourcing risk mitigation measure), what is the optimal cost? Alternatively, if a production facility is limited to supplying no more than 50% of all fertilizer to a single home center (as a supply risk mitigation measure), what is the optimal cost?

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# Parameters
farm_ids = farms['Farm_ID']
processing_ids = processing['Processing_Plant_ID']
center_ids = centers['Center_ID']

farm_capacity = farms.set_index('Farm_ID')['Bio_Material_Capacity_Tons']
farm_cost = farms.set_index('Farm_ID')['Cost_Per_Ton']

# Extract transport costs from farm to processing
farm_to_processing_cost = farms.set_index('Farm_ID').filter(like="Transport_Cost_To_Plant")

processing_capacity = processing.set_index('Processing_Plant_ID')['Capacity_Tons']
processing_cost = processing.set_index('Processing_Plant_ID')['Processing_Cost_Per_Ton']

# Extract transport costs from processing to centers
processing_to_center_cost = processing.set_index('Processing_Plant_ID').filter(like="Transport_Cost_To_Center")

center_demand = centers.set_index('Center_ID')['Requested_Demand_Tons']

# Total raw material sourced from farms
total_raw_material = farm_capacity.sum()

# Create model
model = gp.Model('Transportation_and_Procurement_RiskMitigation')

# Decision variables
x_fp = model.addVars(farm_ids, processing_ids, name="x_fp", lb=0)  # Raw material from farms to processing
x_pc = model.addVars(processing_ids, center_ids, name="x_pc", lb=0)  # Fertilizer from processing to centers

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x_fp[f, p] * (farm_cost[f] + farm_to_processing_cost.loc[f, f'Transport_Cost_To_Plant_{p.split("_")[-1]}'])
        for f in farm_ids for p in processing_ids
    ) +
    gp.quicksum(
        x_pc[p, c] * (processing_cost[p] + processing_to_center_cost.loc[p, f'Transport_Cost_To_Center_{c.split("_")[-1]}'])
        for p in processing_ids for c in center_ids
    ),
    GRB.MINIMIZE
)

# Constraints
# Farm capacity constraints
for f in farm_ids:
    model.addConstr(gp.quicksum(x_fp[f, p] for p in processing_ids) <= farm_capacity[f], f"FarmCapacity_{f}")

# Processing facility capacity constraints
for p in processing_ids:
    model.addConstr(gp.quicksum(x_fp[f, p] for f in farm_ids) <= processing_capacity[p], f"ProcessingCapacity_{p}")

# Center demand constraints
for c in center_ids:
    model.addConstr(gp.quicksum(x_pc[p, c] for p in processing_ids) == center_demand[c], f"CenterDemand_{c}")

# Flow balance constraints: Input to processing equals output
for p in processing_ids:
    model.addConstr(
        gp.quicksum(x_fp[f, p] for f in farm_ids) == gp.quicksum(x_pc[p, c] for c in center_ids),
        f"FlowBalance_{p}"
    )

# 1. Facility Processing Constraint: No more than 3% of total raw material sourced
for p in processing_ids:
    model.addConstr(gp.quicksum(x_fp[f, p] for f in farm_ids) <= 0.03 * total_raw_material, f"MaxProcessing_{p}")

# 2. Facility Supply Constraint: No more than 50% of fertilizer to a single home center
for p in processing_ids:
    for c in center_ids:
        model.addConstr(x_pc[p, c] <= 0.5 * gp.quicksum(x_pc[p, cc] for cc in center_ids), f"MaxSupply_{p}_{c}")

# Solve the model
model.optimize()

# Output the results
if model.status == GRB.OPTIMAL:
    # Output the minimum cost
    print("=" * 50)
    print(f"Optimal Transportation and Procurement Cost (Risk Mitigation): ${model.objVal:,.2f}")
    print("=" * 50)

    # Output detailed solution
    print("\nFarm to Processing Assignments:")
    for f in farm_ids:
        for p in processing_ids:
            if x_fp[f, p].x > 0:
                print(f"Farm {f} -> Processing {p}: {x_fp[f, p].x:.2f} tons")

    print("\nProcessing to Center Assignments:")
    for p in processing_ids:
        for c in center_ids:
            if x_pc[p, c].x > 0:
                print(f"Processing {p} -> Center {c}: {x_pc[p, c].x:.2f} tons")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2241 rows, 6318 columns and 208872 nonzeros
# Model fingerprint: 0xd8387f79
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+00]
#   Objective range  [6e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 3e+04]
# Presolve removed 18 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 2223 rows, 6318 columns, 204390 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.05 seconds (0.15 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      850    2.3118253e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 850 iterations and 0.06 seconds (0.18 work units)
# Optimal objective  2.311825306e+06
# ==================================================
# Optimal Transportation and Procurement Cost (Risk Mitigation): $2,311,825.31
# ==================================================
#
# Farm to Processing Assignments:
# Farm Farm_4 -> Processing Plant_9: 367.00 tons
# Farm Farm_5 -> Processing Plant_5: 119.00 tons
# Farm Farm_5 -> Processing Plant_6: 380.00 tons
# Farm Farm_6 -> Processing Plant_5: 286.00 tons
# Farm Farm_6 -> Processing Plant_13: 131.00 tons
# Farm Farm_14 -> Processing Plant_6: 526.00 tons
# Farm Farm_15 -> Processing Plant_16: 441.00 tons
# Farm Farm_26 -> Processing Plant_2: 564.00 tons
# Farm Farm_31 -> Processing Plant_9: 468.00 tons
# Farm Farm_35 -> Processing Plant_5: 476.00 tons
# Farm Farm_36 -> Processing Plant_10: 519.00 tons
# Farm Farm_38 -> Processing Plant_5: 379.00 tons
# Farm Farm_39 -> Processing Plant_12: 99.00 tons
# Farm Farm_39 -> Processing Plant_15: 390.00 tons
# Farm Farm_43 -> Processing Plant_16: 575.00 tons
# Farm Farm_46 -> Processing Plant_18: 564.00 tons
# Farm Farm_47 -> Processing Plant_16: 552.00 tons
# Farm Farm_52 -> Processing Plant_9: 317.00 tons
# Farm Farm_54 -> Processing Plant_1: 278.00 tons
# Farm Farm_57 -> Processing Plant_2: 306.00 tons
# Farm Farm_62 -> Processing Plant_15: 272.00 tons
# Farm Farm_65 -> Processing Plant_16: 225.00 tons
# Farm Farm_66 -> Processing Plant_1: 409.00 tons
# Farm Farm_67 -> Processing Plant_10: 291.00 tons
# Farm Farm_71 -> Processing Plant_15: 508.00 tons
# Farm Farm_73 -> Processing Plant_9: 386.00 tons
# Farm Farm_76 -> Processing Plant_13: 547.00 tons
# Farm Farm_85 -> Processing Plant_1: 311.00 tons
# Farm Farm_85 -> Processing Plant_4: 37.00 tons
# Farm Farm_86 -> Processing Plant_3: 418.00 tons
# Farm Farm_94 -> Processing Plant_2: 102.00 tons
# Farm Farm_94 -> Processing Plant_6: 473.00 tons
# Farm Farm_99 -> Processing Plant_2: 243.00 tons
# Farm Farm_105 -> Processing Plant_18: 522.00 tons
# Farm Farm_107 -> Processing Plant_10: 457.00 tons
# Farm Farm_108 -> Processing Plant_4: 55.00 tons
# Farm Farm_108 -> Processing Plant_16: 233.00 tons
# Farm Farm_109 -> Processing Plant_15: 397.00 tons
# Farm Farm_110 -> Processing Plant_2: 481.00 tons
# Farm Farm_111 -> Processing Plant_9: 399.00 tons
# Farm Farm_121 -> Processing Plant_2: 213.00 tons
# Farm Farm_121 -> Processing Plant_15: 373.00 tons
# Farm Farm_122 -> Processing Plant_10: 395.00 tons
# Farm Farm_130 -> Processing Plant_9: 504.00 tons
# Farm Farm_130 -> Processing Plant_17: 34.00 tons
# Farm Farm_131 -> Processing Plant_9: 255.00 tons
# Farm Farm_133 -> Processing Plant_10: 337.00 tons
# Farm Farm_135 -> Processing Plant_16: 533.00 tons
# Farm Farm_141 -> Processing Plant_6: 242.00 tons
# Farm Farm_141 -> Processing Plant_9: 332.00 tons
# Farm Farm_142 -> Processing Plant_5: 422.00 tons
# Farm Farm_143 -> Processing Plant_13: 398.00 tons
# Farm Farm_145 -> Processing Plant_16: 486.00 tons
# Farm Farm_147 -> Processing Plant_5: 449.00 tons
# Farm Farm_150 -> Processing Plant_4: 247.00 tons
# Farm Farm_151 -> Processing Plant_5: 308.00 tons
# Farm Farm_155 -> Processing Plant_1: 351.00 tons
# Farm Farm_155 -> Processing Plant_9: 17.00 tons
# Farm Farm_161 -> Processing Plant_15: 472.00 tons
# Farm Farm_165 -> Processing Plant_10: 448.00 tons
# Farm Farm_171 -> Processing Plant_1: 564.00 tons
# Farm Farm_172 -> Processing Plant_5: 289.00 tons
# Farm Farm_183 -> Processing Plant_4: 242.00 tons
# Farm Farm_188 -> Processing Plant_10: 209.00 tons
# Farm Farm_189 -> Processing Plant_2: 495.00 tons
# Farm Farm_192 -> Processing Plant_6: 355.00 tons
# Farm Farm_196 -> Processing Plant_6: 550.00 tons
# Farm Farm_196 -> Processing Plant_10: 23.00 tons
# Farm Farm_203 -> Processing Plant_6: 519.00 tons
# Farm Farm_204 -> Processing Plant_4: 398.00 tons
# Farm Farm_205 -> Processing Plant_4: 555.00 tons
# Farm Farm_206 -> Processing Plant_1: 313.00 tons
# Farm Farm_210 -> Processing Plant_3: 421.00 tons
# Farm Farm_212 -> Processing Plant_10: 366.00 tons
# Farm Farm_213 -> Processing Plant_1: 406.00 tons
# Farm Farm_218 -> Processing Plant_18: 356.00 tons
# Farm Farm_226 -> Processing Plant_2: 386.00 tons
# Farm Farm_238 -> Processing Plant_13: 269.00 tons
# Farm Farm_240 -> Processing Plant_5: 317.00 tons
# Farm Farm_243 -> Processing Plant_1: 413.00 tons
# Farm Farm_244 -> Processing Plant_2: 255.00 tons
#
# Processing to Center Assignments:
# Processing Plant_1 -> Center Center_7: 480.00 tons
# Processing Plant_1 -> Center Center_8: 149.00 tons
# Processing Plant_1 -> Center Center_20: 258.00 tons
# Processing Plant_1 -> Center Center_21: 327.00 tons
# Processing Plant_1 -> Center Center_40: 66.00 tons
# Processing Plant_1 -> Center Center_41: 474.00 tons
# Processing Plant_1 -> Center Center_52: 336.00 tons
# Processing Plant_1 -> Center Center_61: 315.00 tons
# Processing Plant_1 -> Center Center_81: 6.00 tons
# Processing Plant_1 -> Center Center_85: 342.00 tons
# Processing Plant_1 -> Center Center_96: 292.00 tons
# Processing Plant_2 -> Center Center_1: 82.00 tons
# Processing Plant_2 -> Center Center_12: 267.00 tons
# Processing Plant_2 -> Center Center_23: 127.00 tons
# Processing Plant_2 -> Center Center_25: 321.00 tons
# Processing Plant_2 -> Center Center_38: 439.00 tons
# Processing Plant_2 -> Center Center_47: 486.00 tons
# Processing Plant_2 -> Center Center_55: 228.00 tons
# Processing Plant_2 -> Center Center_62: 496.00 tons
# Processing Plant_2 -> Center Center_66: 283.00 tons
# Processing Plant_2 -> Center Center_74: 211.00 tons
# Processing Plant_2 -> Center Center_89: 105.00 tons
# Processing Plant_3 -> Center Center_10: 419.50 tons
# Processing Plant_3 -> Center Center_30: 385.00 tons
# Processing Plant_3 -> Center Center_40: 34.50 tons
# Processing Plant_4 -> Center Center_15: 320.00 tons
# Processing Plant_4 -> Center Center_18: 437.00 tons
# Processing Plant_4 -> Center Center_48: 192.00 tons
# Processing Plant_4 -> Center Center_86: 208.00 tons
# Processing Plant_4 -> Center Center_90: 168.00 tons
# Processing Plant_4 -> Center Center_97: 145.00 tons
# Processing Plant_4 -> Center Center_99: 64.00 tons
# Processing Plant_5 -> Center Center_9: 72.00 tons
# Processing Plant_5 -> Center Center_19: 202.00 tons
# Processing Plant_5 -> Center Center_22: 223.00 tons
# Processing Plant_5 -> Center Center_29: 399.00 tons
# Processing Plant_5 -> Center Center_33: 87.00 tons
# Processing Plant_5 -> Center Center_53: 260.00 tons
# Processing Plant_5 -> Center Center_54: 490.00 tons
# Processing Plant_5 -> Center Center_56: 457.00 tons
# Processing Plant_5 -> Center Center_79: 371.00 tons
# Processing Plant_5 -> Center Center_101: 126.00 tons
# Processing Plant_5 -> Center Center_102: 358.00 tons
# Processing Plant_6 -> Center Center_3: 464.00 tons
# Processing Plant_6 -> Center Center_24: 450.00 tons
# Processing Plant_6 -> Center Center_32: 129.00 tons
# Processing Plant_6 -> Center Center_35: 277.00 tons
# Processing Plant_6 -> Center Center_42: 124.00 tons
# Processing Plant_6 -> Center Center_45: 132.00 tons
# Processing Plant_6 -> Center Center_46: 476.00 tons
# Processing Plant_6 -> Center Center_58: 122.00 tons
# Processing Plant_6 -> Center Center_59: 264.00 tons
# Processing Plant_6 -> Center Center_68: 68.00 tons
# Processing Plant_6 -> Center Center_80: 484.00 tons
# Processing Plant_6 -> Center Center_91: 55.00 tons
# Processing Plant_9 -> Center Center_2: 348.00 tons
# Processing Plant_9 -> Center Center_5: 340.00 tons
# Processing Plant_9 -> Center Center_25: 56.00 tons
# Processing Plant_9 -> Center Center_31: 143.00 tons
# Processing Plant_9 -> Center Center_43: 343.00 tons
# Processing Plant_9 -> Center Center_60: 366.00 tons
# Processing Plant_9 -> Center Center_83: 362.00 tons
# Processing Plant_9 -> Center Center_87: 425.00 tons
# Processing Plant_9 -> Center Center_92: 469.00 tons
# Processing Plant_9 -> Center Center_100: 193.00 tons
# Processing Plant_10 -> Center Center_4: 161.00 tons
# Processing Plant_10 -> Center Center_13: 138.00 tons
# Processing Plant_10 -> Center Center_17: 286.00 tons
# Processing Plant_10 -> Center Center_34: 457.00 tons
# Processing Plant_10 -> Center Center_44: 257.00 tons
# Processing Plant_10 -> Center Center_60: 71.00 tons
# Processing Plant_10 -> Center Center_64: 320.00 tons
# Processing Plant_10 -> Center Center_67: 368.00 tons
# Processing Plant_10 -> Center Center_73: 326.00 tons
# Processing Plant_10 -> Center Center_77: 178.00 tons
# Processing Plant_10 -> Center Center_91: 198.00 tons
# Processing Plant_10 -> Center Center_98: 285.00 tons
# Processing Plant_12 -> Center Center_10: 49.50 tons
# Processing Plant_12 -> Center Center_40: 49.50 tons
# Processing Plant_13 -> Center Center_6: 86.00 tons
# Processing Plant_13 -> Center Center_14: 258.00 tons
# Processing Plant_13 -> Center Center_69: 162.00 tons
# Processing Plant_13 -> Center Center_75: 292.00 tons
# Processing Plant_13 -> Center Center_84: 443.00 tons
# Processing Plant_13 -> Center Center_94: 104.00 tons
# Processing Plant_15 -> Center Center_11: 473.00 tons
# Processing Plant_15 -> Center Center_28: 414.00 tons
# Processing Plant_15 -> Center Center_36: 183.00 tons
# Processing Plant_15 -> Center Center_39: 331.00 tons
# Processing Plant_15 -> Center Center_50: 410.00 tons
# Processing Plant_15 -> Center Center_51: 489.00 tons
# Processing Plant_15 -> Center Center_70: 112.00 tons
# Processing Plant_16 -> Center Center_16: 470.00 tons
# Processing Plant_16 -> Center Center_22: 32.00 tons
# Processing Plant_16 -> Center Center_26: 147.00 tons
# Processing Plant_16 -> Center Center_49: 105.00 tons
# Processing Plant_16 -> Center Center_63: 122.00 tons
# Processing Plant_16 -> Center Center_65: 403.00 tons
# Processing Plant_16 -> Center Center_71: 421.00 tons
# Processing Plant_16 -> Center Center_72: 233.00 tons
# Processing Plant_16 -> Center Center_81: 364.00 tons
# Processing Plant_16 -> Center Center_82: 92.00 tons
# Processing Plant_16 -> Center Center_93: 464.00 tons
# Processing Plant_16 -> Center Center_95: 87.00 tons
# Processing Plant_16 -> Center Center_97: 105.00 tons
# Processing Plant_17 -> Center Center_77: 17.00 tons
# Processing Plant_17 -> Center Center_86: 17.00 tons
# Processing Plant_18 -> Center Center_19: 253.00 tons
# Processing Plant_18 -> Center Center_27: 395.00 tons
# Processing Plant_18 -> Center Center_37: 245.00 tons
# Processing Plant_18 -> Center Center_57: 107.00 tons
# Processing Plant_18 -> Center Center_76: 194.00 tons
# Processing Plant_18 -> Center Center_78: 130.00 tons
# Processing Plant_18 -> Center Center_88: 118.00 tons

# %% [markdown]
# 1. f) Four options were evaluated to understand how changes to the supply chain impacted cost, i.e., see parts (c) through (e). Which of these options (or multiple) are financially defensible, and why? What is the optimal cost when you implement all of the defensible options together?

# %% [markdown]
# 1. g) While implementing all of the defensible options together incurs a higher cost as compared to the original system, it may still represent a strong business decision. How would you concisely defend the implementation of all of the defensible options to management?

# %% [markdown]
# 1. h) The supply chain network has a limited capacity for risk mitigation. To see this, when implementing all of the defensible options from part (f), at what value (to the nearest tenth of a percent) does the model become infeasible when reducing the sourcing risk mitigation percentage from the value given in part (e) of 3%? What is the managerial interpretation of this result, and what are the implications for managing supply chain risk?
